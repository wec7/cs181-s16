# %% [markdown]
# # CS181 Section 2 (Linear Regression)

# %% [markdown]
# <img src="batman.jpeg" style="width:350px">

# %% [markdown]
# In this iPython tutorial, we will be running through a simple linear regression on bat testes. We aim to be able to find correlations between body mass, brain volume and testes mass, while showing how easy it is to pre-process data, train models, and even save models for later use.
#
# First of all, there are different data structures that you can use to represent data. Normally you have python lists, but to perform operations more efficiently, you should convert large datasets into numpy arrays. For multidimensional arrays, you may also consider using pandas dataframes, which have labeled columns and indices.

# %%
# If you have not set up your environment with numpy and matplotlib, follow the installation guide
import pandas as pd
import numpy as np

# %% [markdown]
# The CSV file contains various biological data from several species of
# bats (source: Mating System and brain size in bats, Pitnick et. al.).
# The BodyMass, BrainMass, and TestesMass columns are all in grams.  The
# NeoCortexVolume is in mm^3.  Female Promiscuity indicates whether
# female bats mate with multiple males during their lifetime.  Finally,
# diet=1 indicates a fruit-based diet; diet=2 indicates an "other" diet.

# %%
# Reading in CSV data
mat = pd.read_csv("~/Downloads/bat.csv")
mat
# Out:
#                                        Family  BrainMass  BodyMassBrainStudy  \
# 0                              Emballonuridae       0.26                11.5
# 1                              Emballonuridae       0.12                 3.8
# 2                              Emballonuridae        NaN                 NaN
# 3                              Emballonuridae       0.23                 7.8
# 4                              Emballonuridae       0.16                 5.1
# 5                              Emballonuridae       0.55                29.0
# 6                              Megadermatidae       0.67                26.0
# 7                              Megadermatidae       0.64                23.4
# 8                                  Molossidae       0.28                13.0
# 9                                  Molossidae       0.76                41.5
# 10                                 Molossidae        NaN                 NaN
# 11                              Noctilionidae       1.18                58.0
# 12                                 Nycteridae       0.35                10.6
# 13                                 Nycteridae       0.28                 7.8
# 14                                 Nycteridae       0.24                 6.9
# 15                             Phyllostomidae       0.55                17.8
# 16                             Phyllostomidae        NaN                 NaN
# 17                             Phyllostomidae       1.00                36.3
# 18                             Phyllostomidae       1.09                36.6
# 19                             Phyllostomidae       1.52                90.1
# 20                             Phyllostomidae       2.59               173.0
# 21                               Pteropodidae       1.06                42.4
# 22                               Pteropodidae       7.04               595.0
# 23                               Pteropodidae       7.23               695.0
# 24                               Pteropodidae       5.79               310.0
# 25                               Pteropodidae       5.36               375.0
# 26                               Pteropodidae       9.12              1014.0
# 27                              Rhinolophidae       0.28                10.4
# 28                              Rhinolophidae       0.62                32.8
# 29                           Vespertilionidae       0.31                10.1
# 30                           Vespertilionidae       0.20                 7.1
# 31                           Vespertilionidae        NaN                 NaN
# 32                           Vespertilionidae       0.25                11.2
# 33                           Vespertilionidae       0.13                 4.0
# 34                           Vespertilionidae       0.19                 7.0
# 35                           Vespertilionidae       0.17                 7.9
# 36                           Vespertilionidae       0.49                25.6
# 37                           Vespertilionidae       0.15                 5.6
# 38                           Vespertilionidae       0.36                27.0
# 39                           Vespertilionidae       0.10                 3.9
# 40                           Vespertilionidae        NaN                 NaN
# 41        Vespertilionidae   Plecotus auritus       0.24                 6.6
# 42    Vespertilionidae   Plecotus rafinesquii        NaN                 NaN
# 43   Vespertilionidae   Tylonycteris pachypus       0.08                 4.8
# 44  Vespertilionidae   Tylonycteris robustula       0.12                 7.2
#
#     NeoCortexVolume  TestesMass  BodyMass Female Promiscuity  MatingSystem  \
# 0             52.50        0.03      10.0                 No      polygyny
# 1             22.10        0.02       3.8                 No      polygyny
# 2               NaN        0.58     100.0                 No      monogamy
# 3             43.90        0.01       7.4                 No      polygyny
# 4             30.00        0.03       4.1                 No      monogamy
# 5            105.90         NaN       NaN                NaN      monogamy
# 6            186.30        0.08      26.0                 No      monogamy
# 7            171.40        0.03      23.4                 No      monogamy
# 8             53.25        0.04      10.8                 No      polygyny
# 9            153.60        0.17      36.0                 No      polygyny
# 10              NaN        0.09      11.1                Yes  polygynandry
# 11           361.70        0.18      64.8                 No      polygyny
# 12            89.80         NaN       NaN                 No      monogamy
# 13            69.60         NaN       NaN                 No      monogamy
# 14            54.40         NaN       NaN                 No      monogamy
# 15           129.10        0.13      18.5                 No      polygyny
# 16              NaN        0.18      92.1                 No      monogamy
# 17           312.50        0.08      33.7                 No      polygyny
# 18           312.60        0.65      44.9                 No      polygyny
# 19           438.90        0.31      91.8                 No      polygyny
# 20           757.70        0.20     158.8                 No      monogamy
# 21           352.20        0.36      35.0                Yes  polygynandry
# 22          2716.00        5.10     800.0                Yes  polygynandry
# 23          2710.00        6.75     677.0                Yes  polygynandry
# 24          2144.00         NaN       NaN                 No      monogamy
# 25          2078.00        5.30     400.0                Yes  polygynandry
# 26          3610.00         NaN       NaN                Yes  polygynandry
# 27              NaN        0.06       6.5                 No      monogamy
# 28           135.60         NaN       NaN                 No      monogamy
# 29            69.00         NaN       NaN                 No      monogamy
# 30            37.60        0.04       7.5                 No      polygyny
# 31              NaN        0.05       7.5                Yes  polygynandry
# 32            46.60        0.14      10.0                Yes  polygynandry
# 33            20.50        0.37       5.5                Yes  polygynandry
# 34            36.00        0.08       8.0                 No      polygyny
# 35              NaN        0.11       6.8                Yes  polygynandry
# 36            78.30         NaN       NaN                Yes  polygynandry
# 37            25.65        0.03       4.0                 No      polygyny
# 38            54.90        0.54      27.5                Yes  polygynandry
# 39            15.70        0.03       3.5                Yes  polygynandry
# 40              NaN        0.23       5.0                Yes  polygynandry
# 41              NaN        0.04       7.2                Yes  polygynandry
# 42              NaN        0.75       9.0                Yes  polygynandry
# 43            12.30        0.14       4.1                Yes  polygynandry
# 44            16.70        0.20       8.4                Yes  polygynandry
#
#         Diet
# 0   nonfruit
# 1   nonfruit
# 2   nonfruit
# 3   nonfruit
# 4   nonfruit
# 5   nonfruit
# 6   nonfruit
# 7   nonfruit
# 8   nonfruit
# 9   nonfruit
# 10  nonfruit
# 11  nonfruit
# 12  nonfruit
# 13  nonfruit
# 14  nonfruit
# 15     fruit
# 16  nonfruit
# 17  nonfruit
# 18     fruit
# 19  nonfruit
# 20  nonfruit
# 21     fruit
# 22     fruit
# 23     fruit
# 24     fruit
# 25     fruit
# 26     fruit
# 27  nonfruit
# 28  nonfruit
# 29  nonfruit
# 30  nonfruit
# 31  nonfruit
# 32  nonfruit
# 33  nonfruit
# 34  nonfruit
# 35  nonfruit
# 36  nonfruit
# 37  nonfruit
# 38  nonfruit
# 39  nonfruit
# 40  nonfruit
# 41  nonfruit
# 42  nonfruit
# 43  nonfruit
# 44  nonfruit

# %%
# This gives us aggregate data on our pandas dataframe
mat.describe()

# %%
# There are multiple ways to index by column: using square bracket notation
mat["BrainMass"]
# Out:
# 0     0.26
# 1     0.12
# 2      NaN
# 3     0.23
# 4     0.16
# 5     0.55
# 6     0.67
# 7     0.64
# 8     0.28
# 9     0.76
# 10     NaN
# 11    1.18
# 12    0.35
# 13    0.28
# 14    0.24
# 15    0.55
# 16     NaN
# 17    1.00
# 18    1.09
# 19    1.52
# 20    2.59
# 21    1.06
# 22    7.04
# 23    7.23
# 24    5.79
# 25    5.36
# 26    9.12
# 27    0.28
# 28    0.62
# 29    0.31
# 30    0.20
# 31     NaN
# 32    0.25
# 33    0.13
# 34    0.19
# 35    0.17
# 36    0.49
# 37    0.15
# 38    0.36
# 39    0.10
# 40     NaN
# 41    0.24
# 42     NaN
# 43    0.08
# 44    0.12
# Name: BrainMass, dtype: float64

# %%
# ...or dot notation
mat.BrainMass
# Out:
# 0     0.26
# 1     0.12
# 2      NaN
# 3     0.23
# 4     0.16
# 5     0.55
# 6     0.67
# 7     0.64
# 8     0.28
# 9     0.76
# 10     NaN
# 11    1.18
# 12    0.35
# 13    0.28
# 14    0.24
# 15    0.55
# 16     NaN
# 17    1.00
# 18    1.09
# 19    1.52
# 20    2.59
# 21    1.06
# 22    7.04
# 23    7.23
# 24    5.79
# 25    5.36
# 26    9.12
# 27    0.28
# 28    0.62
# 29    0.31
# 30    0.20
# 31     NaN
# 32    0.25
# 33    0.13
# 34    0.19
# 35    0.17
# 36    0.49
# 37    0.15
# 38    0.36
# 39    0.10
# 40     NaN
# 41    0.24
# 42     NaN
# 43    0.08
# 44    0.12
# Name: BrainMass, dtype: float64

# %%
# Indexing by row
mat.iloc[1]
# Out:
# Family                Emballonuridae
# BrainMass                       0.12
# BodyMassBrainStudy               3.8
# NeoCortexVolume                 22.1
# TestesMass                      0.02
# BodyMass                         3.8
# Female Promiscuity                No
# MatingSystem                polygyny
# Diet                        nonfruit
# Name: 1, dtype: object

# %%
# Converting pandas dataframe to numpy array
npmat = np.array(mat)
npmat
# Out:
# array([['Emballonuridae', 0.26, 11.5, 52.5, 0.03, 10.0, 'No', 'polygyny',
#         'nonfruit'],
#        ['Emballonuridae', 0.12, 3.8, 22.1, 0.02, 3.8, 'No', 'polygyny',
#         'nonfruit'],
#        ['Emballonuridae', nan, nan, nan, 0.58, 100.0, 'No', 'monogamy',
#         'nonfruit'],
#        ['Emballonuridae', 0.23, 7.8, 43.9, 0.01, 7.4, 'No', 'polygyny',
#         'nonfruit'],
#        ['Emballonuridae', 0.16, 5.1, 30.0, 0.03, 4.1, 'No', 'monogamy',
#         'nonfruit'],
#        ['Emballonuridae', 0.55, 29.0, 105.9, nan, nan, nan, 'monogamy',
#         'nonfruit'],
#        ['Megadermatidae', 0.67, 26.0, 186.3, 0.08, 26.0, 'No', 'monogamy',
#         'nonfruit'],
#        ['Megadermatidae', 0.64, 23.4, 171.4, 0.03, 23.4, 'No', 'monogamy',
#         'nonfruit'],
#        ['Molossidae', 0.28, 13.0, 53.25, 0.04, 10.8, 'No', 'polygyny',
#         'nonfruit'],
#        ['Molossidae', 0.76, 41.5, 153.6, 0.17, 36.0, 'No', 'polygyny',
#         'nonfruit'],
#        ['Molossidae', nan, nan, nan, 0.09, 11.1, 'Yes', 'polygynandry',
#         'nonfruit'],
#        ['Noctilionidae', 1.18, 58.0, 361.7, 0.18, 64.8, 'No', 'polygyny',
#         'nonfruit'],
#        ['Nycteridae', 0.35, 10.6, 89.8, nan, nan, 'No', 'monogamy',
#         'nonfruit'],
#        ['Nycteridae', 0.28, 7.8, 69.6, nan, nan, 'No', 'monogamy',
#         'nonfruit'],
#        ['Nycteridae', 0.24, 6.9, 54.4, nan, nan, 'No', 'monogamy',
#         'nonfruit'],
#        ['Phyllostomidae', 0.55, 17.8, 129.1, 0.13, 18.5, 'No', 'polygyny',
#         'fruit'],
#        ['Phyllostomidae', nan, nan, nan, 0.18, 92.1, 'No', 'monogamy',
#         'nonfruit'],
#        ['Phyllostomidae', 1.0, 36.3, 312.5, 0.08, 33.7, 'No', 'polygyny',
#         'nonfruit'],
#        ['Phyllostomidae', 1.09, 36.6, 312.6, 0.65, 44.9, 'No', 'polygyny',
#         'fruit'],
#        ['Phyllostomidae', 1.52, 90.1, 438.9, 0.31, 91.8, 'No', 'polygyny',
#         'nonfruit'],
#        ['Phyllostomidae', 2.59, 173.0, 757.7, 0.2, 158.8, 'No', 'monogamy',
#         'nonfruit'],
#        ['Pteropodidae', 1.06, 42.4, 352.2, 0.36, 35.0, 'Yes',
#         'polygynandry', 'fruit'],
#        ['Pteropodidae', 7.04, 595.0, 2716.0, 5.1, 800.0, 'Yes',
#         'polygynandry', 'fruit'],
#        ['Pteropodidae', 7.23, 695.0, 2710.0, 6.75, 677.0, 'Yes',
#         'polygynandry', 'fruit'],
#        ['Pteropodidae', 5.79, 310.0, 2144.0, nan, nan, 'No', 'monogamy',
#         'fruit'],
#        ['Pteropodidae', 5.36, 375.0, 2078.0, 5.3, 400.0, 'Yes',
#         'polygynandry', 'fruit'],
#        ['Pteropodidae', 9.12, 1014.0, 3610.0, nan, nan, 'Yes',
#         'polygynandry', 'fruit'],
#        ['Rhinolophidae', 0.28, 10.4, nan, 0.06, 6.5, 'No', 'monogamy',
#         'nonfruit'],
#        ['Rhinolophidae', 0.62, 32.8, 135.6, nan, nan, 'No', 'monogamy',
#         'nonfruit'],
#        ['Vespertilionidae', 0.31, 10.1, 69.0, nan, nan, 'No', 'monogamy',
#         'nonfruit'],
#        ['Vespertilionidae', 0.2, 7.1, 37.6, 0.04, 7.5, 'No', 'polygyny',
#         'nonfruit'],
#        ['Vespertilionidae', nan, nan, nan, 0.05, 7.5, 'Yes',
#         'polygynandry', 'nonfruit'],
#        ['Vespertilionidae', 0.25, 11.2, 46.6, 0.14, 10.0, 'Yes',
#         'polygynandry', 'nonfruit'],
#        ['Vespertilionidae', 0.13, 4.0, 20.5, 0.37, 5.5, 'Yes',
#         'polygynandry', 'nonfruit'],
#        ['Vespertilionidae', 0.19, 7.0, 36.0, 0.08, 8.0, 'No', 'polygyny',
#         'nonfruit'],
#        ['Vespertilionidae', 0.17, 7.9, nan, 0.11, 6.8, 'Yes',
#         'polygynandry', 'nonfruit'],
#        ['Vespertilionidae', 0.49, 25.6, 78.3, nan, nan, 'Yes',
#         'polygynandry', 'nonfruit'],
#        ['Vespertilionidae', 0.15, 5.6, 25.65, 0.03, 4.0, 'No', 'polygyny',
#         'nonfruit'],
#        ['Vespertilionidae', 0.36, 27.0, 54.9, 0.54, 27.5, 'Yes',
#         'polygynandry', 'nonfruit'],
#        ['Vespertilionidae', 0.1, 3.9, 15.7, 0.03, 3.5, 'Yes',
#         'polygynandry', 'nonfruit'],
#        ['Vespertilionidae', nan, nan, nan, 0.23, 5.0, 'Yes',
#         'polygynandry', 'nonfruit'],
#        ['Vespertilionidae   Plecotus auritus', 0.24, 6.6, nan, 0.04, 7.2,
#         'Yes', 'polygynandry', 'nonfruit'],
#        ['Vespertilionidae   Plecotus rafinesquii', nan, nan, nan, 0.75,
#         9.0, 'Yes', 'polygynandry', 'nonfruit'],
#        ['Vespertilionidae   Tylonycteris pachypus', 0.08, 4.8, 12.3, 0.14,
#         4.1, 'Yes', 'polygynandry', 'nonfruit'],
#        ['Vespertilionidae   Tylonycteris robustula', 0.12, 7.2, 16.7, 0.2,
#         8.4, 'Yes', 'polygynandry', 'nonfruit']], dtype=object)

# %%
# Or to a list
npmat.tolist()
# Out:
# [['Emballonuridae',
#   0.26,
#   11.5,
#   52.5,
#   0.03,
#   10.0,
#   'No',
#   'polygyny',
#   'nonfruit'],
#  ['Emballonuridae', 0.12, 3.8, 22.1, 0.02, 3.8, 'No', 'polygyny', 'nonfruit'],
#  ['Emballonuridae', nan, nan, nan, 0.58, 100.0, 'No', 'monogamy', 'nonfruit'],
#  ['Emballonuridae', 0.23, 7.8, 43.9, 0.01, 7.4, 'No', 'polygyny', 'nonfruit'],
#  ['Emballonuridae', 0.16, 5.1, 30.0, 0.03, 4.1, 'No', 'monogamy', 'nonfruit'],
#  ['Emballonuridae', 0.55, 29.0, 105.9, nan, nan, nan, 'monogamy', 'nonfruit'],
#  ['Megadermatidae',
#   0.67,
#   26.0,
#   186.3,
#   0.08,
#   26.0,
#   'No',
#   'monogamy',
#   'nonfruit'],
#  ['Megadermatidae',
#   0.64,
#   23.4,
#   171.4,
#   0.03,
#   23.4,
#   'No',
#   'monogamy',
#   'nonfruit'],
#  ['Molossidae', 0.28, 13.0, 53.25, 0.04, 10.8, 'No', 'polygyny', 'nonfruit'],
#  ['Molossidae', 0.76, 41.5, 153.6, 0.17, 36.0, 'No', 'polygyny', 'nonfruit'],
#  ['Molossidae', nan, nan, nan, 0.09, 11.1, 'Yes', 'polygynandry', 'nonfruit'],
#  ['Noctilionidae',
#   1.18,
#   58.0,
#   361.7,
#   0.18,
#   64.8,
#   'No',
#   'polygyny',
#   'nonfruit'],
#  ['Nycteridae', 0.35, 10.6, 89.8, nan, nan, 'No', 'monogamy', 'nonfruit'],
#  ['Nycteridae', 0.28, 7.8, 69.6, nan, nan, 'No', 'monogamy', 'nonfruit'],
#  ['Nycteridae', 0.24, 6.9, 54.4, nan, nan, 'No', 'monogamy', 'nonfruit'],
#  ['Phyllostomidae', 0.55, 17.8, 129.1, 0.13, 18.5, 'No', 'polygyny', 'fruit'],
#  ['Phyllostomidae', nan, nan, nan, 0.18, 92.1, 'No', 'monogamy', 'nonfruit'],
#  ['Phyllostomidae',
#   1.0,
#   36.3,
#   312.5,
#   0.08,
#   33.7,
#   'No',
#   'polygyny',
#   'nonfruit'],
#  ['Phyllostomidae', 1.09, 36.6, 312.6, 0.65, 44.9, 'No', 'polygyny', 'fruit'],
#  ['Phyllostomidae',
#   1.52,
#   90.1,
#   438.9,
#   0.31,
#   91.8,
#   'No',
#   'polygyny',
#   'nonfruit'],
#  ['Phyllostomidae',
#   2.59,
#   173.0,
#   757.7,
#   0.2,
#   158.8,
#   'No',
#   'monogamy',
#   'nonfruit'],
#  ['Pteropodidae',
#   1.06,
#   42.4,
#   352.2,
#   0.36,
#   35.0,
#   'Yes',
#   'polygynandry',
#   'fruit'],
#  ['Pteropodidae',
#   7.04,
#   595.0,
#   2716.0,
#   5.1,
#   800.0,
#   'Yes',
#   'polygynandry',
#   'fruit'],
#  ['Pteropodidae',
#   7.23,
#   695.0,
#   2710.0,
#   6.75,
#   677.0,
#   'Yes',
#   'polygynandry',
#   'fruit'],
#  ['Pteropodidae', 5.79, 310.0, 2144.0, nan, nan, 'No', 'monogamy', 'fruit'],
#  ['Pteropodidae',
#   5.36,
#   375.0,
#   2078.0,
#   5.3,
#   400.0,
#   'Yes',
#   'polygynandry',
#   'fruit'],
#  ['Pteropodidae',
#   9.12,
#   1014.0,
#   3610.0,
#   nan,
#   nan,
#   'Yes',
#   'polygynandry',
#   'fruit'],
#  ['Rhinolophidae', 0.28, 10.4, nan, 0.06, 6.5, 'No', 'monogamy', 'nonfruit'],
#  ['Rhinolophidae', 0.62, 32.8, 135.6, nan, nan, 'No', 'monogamy', 'nonfruit'],
#  ['Vespertilionidae',
#   0.31,
#   10.1,
#   69.0,
#   nan,
#   nan,
#   'No',
#   'monogamy',
#   'nonfruit'],
#  ['Vespertilionidae', 0.2, 7.1, 37.6, 0.04, 7.5, 'No', 'polygyny', 'nonfruit'],
#  ['Vespertilionidae',
#   nan,
#   nan,
#   nan,
#   0.05,
#   7.5,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae',
#   0.25,
#   11.2,
#   46.6,
#   0.14,
#   10.0,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae',
#   0.13,
#   4.0,
#   20.5,
#   0.37,
#   5.5,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae',
#   0.19,
#   7.0,
#   36.0,
#   0.08,
#   8.0,
#   'No',
#   'polygyny',
#   'nonfruit'],
#  ['Vespertilionidae',
#   0.17,
#   7.9,
#   nan,
#   0.11,
#   6.8,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae',
#   0.49,
#   25.6,
#   78.3,
#   nan,
#   nan,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae',
#   0.15,
#   5.6,
#   25.65,
#   0.03,
#   4.0,
#   'No',
#   'polygyny',
#   'nonfruit'],
#  ['Vespertilionidae',
#   0.36,
#   27.0,
#   54.9,
#   0.54,
#   27.5,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae',
#   0.1,
#   3.9,
#   15.7,
#   0.03,
#   3.5,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae',
#   nan,
#   nan,
#   nan,
#   0.23,
#   5.0,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae   Plecotus auritus',
#   0.24,
#   6.6,
#   nan,
#   0.04,
#   7.2,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae   Plecotus rafinesquii',
#   nan,
#   nan,
#   nan,
#   0.75,
#   9.0,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae   Tylonycteris pachypus',
#   0.08,
#   4.8,
#   12.3,
#   0.14,
#   4.1,
#   'Yes',
#   'polygynandry',
#   'nonfruit'],
#  ['Vespertilionidae   Tylonycteris robustula',
#   0.12,
#   7.2,
#   16.7,
#   0.2,
#   8.4,
#   'Yes',
#   'polygynandry',
#   'nonfruit']]

# %%
# Sanitizing data by dropping rows with missing values
mat2 = mat.dropna()
mat2
# Out:
#                                        Family  BrainMass  BodyMassBrainStudy  \
# 0                              Emballonuridae       0.26                11.5
# 1                              Emballonuridae       0.12                 3.8
# 3                              Emballonuridae       0.23                 7.8
# 4                              Emballonuridae       0.16                 5.1
# 6                              Megadermatidae       0.67                26.0
# 7                              Megadermatidae       0.64                23.4
# 8                                  Molossidae       0.28                13.0
# 9                                  Molossidae       0.76                41.5
# 11                              Noctilionidae       1.18                58.0
# 15                             Phyllostomidae       0.55                17.8
# 17                             Phyllostomidae       1.00                36.3
# 18                             Phyllostomidae       1.09                36.6
# 19                             Phyllostomidae       1.52                90.1
# 20                             Phyllostomidae       2.59               173.0
# 21                               Pteropodidae       1.06                42.4
# 22                               Pteropodidae       7.04               595.0
# 23                               Pteropodidae       7.23               695.0
# 25                               Pteropodidae       5.36               375.0
# 30                           Vespertilionidae       0.20                 7.1
# 32                           Vespertilionidae       0.25                11.2
# 33                           Vespertilionidae       0.13                 4.0
# 34                           Vespertilionidae       0.19                 7.0
# 37                           Vespertilionidae       0.15                 5.6
# 38                           Vespertilionidae       0.36                27.0
# 39                           Vespertilionidae       0.10                 3.9
# 43   Vespertilionidae   Tylonycteris pachypus       0.08                 4.8
# 44  Vespertilionidae   Tylonycteris robustula       0.12                 7.2
#
#     NeoCortexVolume  TestesMass  BodyMass Female Promiscuity  MatingSystem  \
# 0             52.50        0.03      10.0                 No      polygyny
# 1             22.10        0.02       3.8                 No      polygyny
# 3             43.90        0.01       7.4                 No      polygyny
# 4             30.00        0.03       4.1                 No      monogamy
# 6            186.30        0.08      26.0                 No      monogamy
# 7            171.40        0.03      23.4                 No      monogamy
# 8             53.25        0.04      10.8                 No      polygyny
# 9            153.60        0.17      36.0                 No      polygyny
# 11           361.70        0.18      64.8                 No      polygyny
# 15           129.10        0.13      18.5                 No      polygyny
# 17           312.50        0.08      33.7                 No      polygyny
# 18           312.60        0.65      44.9                 No      polygyny
# 19           438.90        0.31      91.8                 No      polygyny
# 20           757.70        0.20     158.8                 No      monogamy
# 21           352.20        0.36      35.0                Yes  polygynandry
# 22          2716.00        5.10     800.0                Yes  polygynandry
# 23          2710.00        6.75     677.0                Yes  polygynandry
# 25          2078.00        5.30     400.0                Yes  polygynandry
# 30            37.60        0.04       7.5                 No      polygyny
# 32            46.60        0.14      10.0                Yes  polygynandry
# 33            20.50        0.37       5.5                Yes  polygynandry
# 34            36.00        0.08       8.0                 No      polygyny
# 37            25.65        0.03       4.0                 No      polygyny
# 38            54.90        0.54      27.5                Yes  polygynandry
# 39            15.70        0.03       3.5                Yes  polygynandry
# 43            12.30        0.14       4.1                Yes  polygynandry
# 44            16.70        0.20       8.4                Yes  polygynandry
#
#         Diet
# 0   nonfruit
# 1   nonfruit
# 3   nonfruit
# 4   nonfruit
# 6   nonfruit
# 7   nonfruit
# 8   nonfruit
# 9   nonfruit
# 11  nonfruit
# 15     fruit
# 17  nonfruit
# 18     fruit
# 19  nonfruit
# 20  nonfruit
# 21     fruit
# 22     fruit
# 23     fruit
# 25     fruit
# 30  nonfruit
# 32  nonfruit
# 33  nonfruit
# 34  nonfruit
# 37  nonfruit
# 38  nonfruit
# 39  nonfruit
# 43  nonfruit
# 44  nonfruit

# %%
# Finding categorical vs continuous features
categorical = []
for x in mat2:
    if type(mat[x][0]) is str:
        categorical.append(x)
categorical
# Out:
# ['Family', 'Female Promiscuity', 'MatingSystem', 'Diet']

# %%
# Look at continuous features only - in our simplified version of linear regression
num_df = mat2.drop(categorical, axis=1)
num_df
# Out:
#     BrainMass  BodyMassBrainStudy  NeoCortexVolume  TestesMass  BodyMass
# 0        0.26                11.5            52.50        0.03      10.0
# 1        0.12                 3.8            22.10        0.02       3.8
# 3        0.23                 7.8            43.90        0.01       7.4
# 4        0.16                 5.1            30.00        0.03       4.1
# 6        0.67                26.0           186.30        0.08      26.0
# 7        0.64                23.4           171.40        0.03      23.4
# 8        0.28                13.0            53.25        0.04      10.8
# 9        0.76                41.5           153.60        0.17      36.0
# 11       1.18                58.0           361.70        0.18      64.8
# 15       0.55                17.8           129.10        0.13      18.5
# 17       1.00                36.3           312.50        0.08      33.7
# 18       1.09                36.6           312.60        0.65      44.9
# 19       1.52                90.1           438.90        0.31      91.8
# 20       2.59               173.0           757.70        0.20     158.8
# 21       1.06                42.4           352.20        0.36      35.0
# 22       7.04               595.0          2716.00        5.10     800.0
# 23       7.23               695.0          2710.00        6.75     677.0
# 25       5.36               375.0          2078.00        5.30     400.0
# 30       0.20                 7.1            37.60        0.04       7.5
# 32       0.25                11.2            46.60        0.14      10.0
# 33       0.13                 4.0            20.50        0.37       5.5
# 34       0.19                 7.0            36.00        0.08       8.0
# 37       0.15                 5.6            25.65        0.03       4.0
# 38       0.36                27.0            54.90        0.54      27.5
# 39       0.10                 3.9            15.70        0.03       3.5
# 43       0.08                 4.8            12.30        0.14       4.1
# 44       0.12                 7.2            16.70        0.20       8.4

# %%
# Compute linear regression fit to predict TestesMass based on all continuous features
import sklearn.linear_model
model = sklearn.linear_model.LinearRegression()
# Explicitly isolate TestesMass
targ_df = num_df["TestesMass"]
features = num_df.drop("TestesMass", axis=1)
model.fit(features, targ_df)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Examine linear regression coefficients and intercept - what do these represent?
print model.coef_
print model.intercept_
# Out:
# [-2.75850971  0.01118727  0.00897371 -0.00839727]
# 0.298518940153

# %%
# R^2
model.score(features, targ_df)
# Out:
# 0.98032662179803698

# %%
# Examining residuals
resids = targ_df - model.predict(features)
resids
# Out:
# 0    -0.067107
# 1    -0.156419
# 3    -0.073128
# 4    -0.118995
# 6    -0.114659
# 7    -0.106452
# 8    -0.018730
# 9     0.427617
# 11   -0.213985
# 15    0.146372
# 17   -0.387402
# 18    0.520660
# 19    0.028753
# 20   -0.355266
# 21   -0.355473
# 22   -0.089802
# 23   -0.013435
# 25    0.303416
# 30   -0.060678
# 32    0.071609
# 33    0.247562
# 34   -0.028588
# 37   -0.113978
# 38    0.670757
# 39   -0.147795
# 43   -0.067485
# 44    0.072630
# Name: TestesMass, dtype: float64

# %%
# Save model for future use
import pickle
s = pickle.dumps(model)
f = open("test.txt", "wb")
f.write(s)
f.close()

# %%
import numpy as np
import matplotlib
import matplotlib.mlab as mlab

# This is a window you can add stuff to
import matplotlib.pyplot as plt

# The histogram of the residuals
plt.hist(resids, bins=20, normed=True)

plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residuals')

# Should show up in a separate window titled "Python 2.7" or similar
plt.show()
# Out:
# ERROR: Line magic function `%inline` not found.

# %%
import numpy as np
import matplotlib
import matplotlib.mlab as mlab

# This is a window you can add stuff to
import matplotlib.pyplot as plt

plt.scatter(num_df["BrainMass"], num_df["NeoCortexVolume"])
plt.xlabel("BrainMass")
plt.ylabel("NeoCortexVolume")
plt.show()

# %% [markdown]
# ### Your turn!
#
# - Conduct exploratory analysis on BodyMass, TestesMass, BrainMass, and NeoCortexVolume. Describe and provide a possible explanation for the correlations that you see.
# - Compute a linear regression fit to predict TestesMass based on BrainMass alone, BodyMass alone, and BrainMass and BodyMass together, all in log units. Plot residuals against FemalePromiscuity, MatingSystem, and Diet.
# - Take a random half of the data and train on that, then evaluate on the other half (cross-validation)
# - Try plotting things! For example, you could add a linear regression line to a scatter plot.
